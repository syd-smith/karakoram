# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from netCDF4 import Dataset
import numpy as np
from pathlib import Path
import sys
from wrf import (CoordPair, getvar, to_np, vertcross)


# ==================================
# - Establish Relative File Path - 
# ==================================

current_file_directory = Path(__file__).resolve().parent
# parent_directory = current_file_directory.parent
sys.path.append(str(current_file_directory))

from anomalies import data_access
import from_savanna.nclcmaps as cmap



def load_variables(experiment):

    # access all variables necessary for cross section
    qvapor = data_access('QVAPOR', 7, 'd01', experiment)
    ua = data_access('ua', 7, 'd01', experiment)
    va = data_access('va', 7, 'd01', experiment)
    ht = data_access('z', 7, 'd01', experiment)

    return qvapor, ua, va, ht

noise_qvapor, noise_ua, noise_va, noise_ht = load_variables('noise')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 35
#      31     ht = data_access('z', 7, 'd01', experiment)
#      33     return qvapor, ua, va, ht
# ---> 35 noise_qvapor, noise_ua, noise_va, noise_ht = load_variables('noise')
#
# Cell In[4], line 28, in load_variables(experiment)
#      25 def load_variables(experiment):
#      26
#      27     # access all variables necessary for cross section
# ---> 28     qvapor = data_access('QVAPOR', 7, 'd01', experiment)
#      29     ua = data_access('ua', 7, 'd01', experiment)
#      30     va = data_access('va', 7, 'd01', experiment)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/karakoram/anomalies.py:70, in data_access(variable, month, domain, experiment)
#      66 # if data for given variable is provided as an instantaneous result at that timestamp
#      67 else:
#      68     # create a list with all control experiment files and open them
#      69     collect_files = sorted(glob.glob(str(path / f'wrfout_{domain}_{year}-0{month}*')))
# ---> 70     open_files = [Dataset(file) for file in collect_files]
#      72     # compile control data into one netcdf
#      73     instantaneous = getvar(open_files, variable, timeidx = ALL_TIMES)
#
# File /uufs/chpc.utah.edu/common/home/strong-group7/sydney/karakoram/anomalies.py:70, in <listcomp>(.0)
#      66 # if data for given variable is provided as an instantaneous result at that timestamp
#      67 else:
#      68     # create a list with all control experiment files and open them
#      69     collect_files = sorted(glob.glob(str(path / f'wrfout_{domain}_{year}-0{month}*')))
# ---> 70     open_files = [Dataset(file) for file in collect_files]
#      72     # compile control data into one netcdf
#      73     instantaneous = getvar(open_files, variable, timeidx = ALL_TIMES)
#
# File src/netCDF4/_netCDF4.pyx:2522, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2159, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/uufs/chpc.utah.edu/common/home/strong-group7/sydney/karakoram/wrfout/wrfout_noise/2016/wrfout_d01_2016-07-01_00:00:00'
